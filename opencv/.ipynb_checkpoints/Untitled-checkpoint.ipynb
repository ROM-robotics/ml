# %%
import cv2 as cv

def main():
    name = "Video Player"
    cv.namedWindow(name)    
     
    cap = cv.VideoCapture('output.avi')    
  
    while cap.isOpened():
        ret,frame = cap.read()
        print(ret)
        if(ret):
            cv.imshow(name,frame)
            k = cv.waitKey(1) # 33 ,100
            if k == 27:
                break
        else:
            break
            
    cv.destroyAllWindows()
    cap.release()
    


if __name__ == "__main__":
    main()
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ဖိုင်ကို run ကြည့်ရင် အရမ်းမြန်နေတာကို တွေ့ရပါမယ် video ကို write လုပ်စဥ်တုန်းက framerate က 30 ပါ 30 fps ပါ
# time = 1/frequency ဆိုတော့ 0.333333 seconds ရပါတယ်။ cv2.waitKey() method က milli seconds ဆိုတော့ 0.3333 s = 33 ms ပါ
# စမ်းကြည့်ပါ။ slow motion လုပ်ချင်ရင် အချိန်ကို များလိုက်ပါ။
