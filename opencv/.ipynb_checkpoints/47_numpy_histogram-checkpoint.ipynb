# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

def main():
    img = cv.imread('4.2.07.tiff',0)
    
    img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
    
    r,g,b = cv.split(img)

    plt.subplot(2,3,1)
    plt.imshow(img)
    plt.title('Image')
    plt.xticks([])
    plt.yticks([])
    
    plt.subplot(2,3,2)
    hist,bins = np.histogram(img.ravel(),256,[0,255]) # ravel is flatten image
    plt.plot(hist)
    plt.title('histogram')
    plt.xlim(xmin=0,xmax=256)
    plt.ylim([0,3000])
    
    plt.subplot(2,3,3)
    hist,bins = np.histogram(r.ravel(),256,[0,255]) # ravel is flatten image
    plt.plot(hist, color='r')
    plt.title('red histogram')
    plt.xlim(xmin=0,xmax=256)
    plt.show()
    
    plt.subplot(2,3,4)
    hist,bins = np.histogram(g.ravel(),256,[0,255]) # ravel is flatten image
    plt.plot(hist, color='g')
    plt.title('green histogram')
    plt.xlim(xmin=0,xmax=256)
    plt.show()
    
    plt.subplot(2,3,5)
    hist,bins = np.histogram(b.ravel(),256,[0,255]) # ravel is flatten image
    plt.plot(hist, color='b')
    plt.title('blue histogram')
    plt.xlim(xmin=0,xmax=256)
    plt.show()
    
    
    plt.show()
    
if __name__ == "__main__":
    main()
