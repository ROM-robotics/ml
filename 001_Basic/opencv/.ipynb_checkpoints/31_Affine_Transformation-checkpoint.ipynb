# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

def main():
    img = cv.imread('images/4.2.01.tiff')
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    row,column,channel = img.shape
    
    point1 = np.float32([[100,100],[300,100],[100,300]])
    point2 = np.float32([[200,150],[400,150],[400,300]])
    #point2 = np.float32([[200,150],[400,150],[100,400]])
    
    A = cv.getAffineTransform(point1,point2)
    print(A)
    
    output = cv.warpAffine(img, A, (column,row))
    
    plt.imshow(output)
    plt.title('Affine Transform')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[ 1.00000000e+00  1.00000000e+00  2.84217094e-14]
#  [-9.47390314e-17  7.50000000e-01  7.50000000e+01]]
