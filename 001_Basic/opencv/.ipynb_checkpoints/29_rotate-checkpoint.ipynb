# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

def main():
    img = cv.imread('images/4.2.01.tiff')
    img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
    
    row,col,ch = img.shape
    
    R = cv.getRotationMatrix2D( (col/2, row/2), 90, 0.5)
    print(R)
    
    output = cv.warpAffine( img,R,(col,row) )
 
    
    plt.imshow(output)
    plt.title('rotating')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
# [[ 3.061617e-17  5.000000e-01  1.280000e+02]
#  [-5.000000e-01  3.061617e-17  3.840000e+02]]

# %% [markdown]
# Translation is shifting image
#
# T = [[1,0,50],
#      [0,1,50]]
# cv2.wrapAffine()
